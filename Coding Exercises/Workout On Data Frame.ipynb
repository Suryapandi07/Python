# %%
import pandas as pd

# %%
a2 = pd.read_csv("loandata.csv")

# %%
a2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001722    Male     Yes          0      Graduate            No
# 1    LP002502  Female     Yes          2  Not Graduate           NaN
# 2    LP002949  Female      No         3+      Graduate           NaN
# 3    LP002603  Female      No          0      Graduate            No
# 4    LP001644     NaN     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP001640    Male     Yes          0      Graduate           Yes
# 610  LP001536    Male     Yes         3+      Graduate            No
# 611  LP001585     NaN     Yes         3+      Graduate            No
# 612  LP002101    Male     Yes          0      Graduate           NaN
# 613  LP002317    Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
a2['Gender'].replace('Male','1',inplace=True)
a2['Gender'].replace('Female','0',inplace=True)
a2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001722      1     Yes          0      Graduate            No
# 1    LP002502      0     Yes          2  Not Graduate           NaN
# 2    LP002949      0      No         3+      Graduate           NaN
# 3    LP002603      0      No          0      Graduate            No
# 4    LP001644    NaN     Yes          0      Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 609  LP001640      1     Yes          0      Graduate           Yes
# 610  LP001536      1     Yes         3+      Graduate            No
# 611  LP001585    NaN     Yes         3+      Graduate            No
# 612  LP002101      1     Yes          0      Graduate           NaN
# 613  LP002317      1     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
a2['Married'].replace('Yes','1',inplace=True)
a2['Married'].replace('No','0',inplace=True)
a2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001722      1       1          0      Graduate            No
# 1    LP002502      0       1          2  Not Graduate           NaN
# 2    LP002949      0       0         3+      Graduate           NaN
# 3    LP002603      0       0          0      Graduate            No
# 4    LP001644    NaN       1          0      Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 609  LP001640      1       1          0      Graduate           Yes
# 610  LP001536      1       1         3+      Graduate            No
# 611  LP001585    NaN       1         3+      Graduate            No
# 612  LP002101      1       1          0      Graduate           NaN
# 613  LP002317      1       1         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                150             1800.0       135.0             360.0
# ...

# %%
new_data = []
for i in a2['ApplicantIncome']:
    if i <= 5000:
        i = i+10000
        new_data.append(i)
    else:
        new_data.append(i)
a2['ApplicantIncome'] = new_data
a2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001722      1       1          0      Graduate            No
# 1    LP002502      0       1          2  Not Graduate           NaN
# 2    LP002949      0       0         3+      Graduate           NaN
# 3    LP002603      0       0          0      Graduate            No
# 4    LP001644    NaN       1          0      Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 609  LP001640      1       1          0      Graduate           Yes
# 610  LP001536      1       1         3+      Graduate            No
# 611  LP001585    NaN       1         3+      Graduate            No
# 612  LP002101      1       1          0      Graduate           NaN
# 613  LP002317      1       1         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              10150             1800.0       135.0             360.0
# ...
